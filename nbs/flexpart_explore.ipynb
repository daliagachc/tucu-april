# %%
# %run ./tucu-saltena-fun.ipynb

# %%
import os
import glob
import pandas as pd
import matplotlib.pyplot as plt
from netCDF4 import Dataset as netcdf_dataset
import netCDF4
import xarray as xr

# %%
path =  '../tucu-april-rm-data/flex_data_out/header_d01.nc'

# %%
xa = xr.open_dataset(path)
xa.XLONG.plot()

# %%
xa.XLAT.plot()

# %%
xa.TOPOGRAPHY.plot()

# %%
xa
# Out:
# <xarray.Dataset>
# Dimensions:            (ReleaseStartEnd: 2, Time: 0, ageclass: 1, bottom_top: 16, receptors: 0, releases: 1, south_north: 300, species: 1, west_east: 288)
# Coordinates:
#     XLONG              (south_north, west_east) float32 ...
#     XLAT               (south_north, west_east) float32 ...
# Dimensions without coordinates: ReleaseStartEnd, Time, ageclass, bottom_top, receptors, releases, south_north, species, west_east
# Data variables:
#     XLONG_CORNER       (south_north, west_east) float32 ...
#     XLAT_CORNER        (south_north, west_east) float32 ...
#     ZTOP               (bottom_top) float32 ...
#     SPECIES            (species) |S10 ...
#     AGECLASS           (ageclass) int32 ...
#     Times              (Time) |S15
#     ReleaseName        (releases) |S45 ...
#     ReleaseTstart_end  (releases, ReleaseStartEnd) int32 ...
#     ReleaseXstart_end  (releases, ReleaseStartEnd) float32 ...
# ...
